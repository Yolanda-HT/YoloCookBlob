# %%
import glob
import csv
import pandas as pd
import numpy as np
import math
from datetime import datetime
from re import finditer

def camel_case_split(identifier):
    matches = finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

# %%
###----- Input out put setup
# Output
out_file = "Salad_Planner.md"

# Input db
db_file = "Salad_planner_database.xlsx"
db_df = pd.read_excel(db_file)

# Input plots
plot_dir = "Salad_planner_database_plots"
plots_list = glob.glob("%s/*.png"%plot_dir)
plots_dict = {x.split("/")[1].split("___")[0]:x for x in plots_list}

###----- Setup
# Emoji dictionary for each category
type_emoji_dict = {'LeafyGreens': ":leafy_green:",
                   'RawUnseasonedVeggies': ":cucumber:",
                   'LightDressingSeasoning': ":salt:",
                   'Fruits':":blueberries:",
                   'SeasonedCookedVeggies': ":stew:",
                   'HerbFlavor': ":garlic:",
                   'Carb': ":baguette_bread:",
                   'ProteinFat': ":poultry_leg:",
                   'HeavyDressingSeasoning': ":butter:"}
col_n = 5

# %%
se
# Out:
# 0     LFG_1
# 1     LFG_2
# 2     LFG_3
# 3     LFG_4
# 4     LFG_5
#       ...
# 67    LDS_1
# 68    LDS_2
# 69    LDS_3
# 70    LDS_4
# 71    HDS_1
# Name: ID, Length: 72, dtype: object

# %%
plots_dict
# Out:
# {'RUV_3': 'Salad_planner_database_plots/RUV_3___Carrots.png',
#  'HBF_7': 'Salad_planner_database_plots/HBF_7___Roasted_garlic.png',
#  'FRT_3': 'Salad_planner_database_plots/FRT_3___Mango.png',
#  'LFG_6': 'Salad_planner_database_plots/LFG_6___Arugula.png',
#  'LFG_1': 'Salad_planner_database_plots/LFG_1___Mixed_Baby_Greens.png',
#  'FRT_10': 'Salad_planner_database_plots/FRT_10___Tangerines.png',
#  'CRB_10': 'Salad_planner_database_plots/CRB_10___Wild_rice.png',
#  'CRB_7': 'Salad_planner_database_plots/CRB_7___Corn.png',
#  'LDS_1': 'Salad_planner_database_plots/LDS_1___Sriracha.png',
#  'LFG_7': 'Salad_planner_database_plots/LFG_7___Endive.png',
#  'SCV_1': 'Salad_planner_database_plots/SCV_1___Broccoli-cauliflower_(air_fried-roasted).png',
#  'LDS_3': 'Salad_planner_database_plots/LDS_3___Lemon_juice.png',
#  'PRT_12': 'Salad_planner_database_plots/PRT_12___Bacon_crumbles.png',
#  'PRT_1': 'Salad_planner_database_plots/PRT_1___Hard_boiled_egg.png',
#  'FRT_1': 'Salad_planner_database_plots/FRT_1___Papaya.png',
#  'FRT_6': 'Salad_planner_database_plots/FRT_6___Strawberries.png',
#  'HBF_2': 'Salad_planner_database_plots/HBF_2___Mint-lemon_balm.png',
#  'HBF_3': 'Salad_planner_database_plots/HBF_3___Dill.png',
#  'PRT_10': 'Salad_planner_database_plots/PRT_10___Grilled_white_fish_(Tilapia).png',
#  'CRB_14': 'Salad_planner_database_plots/CRB_14___Raisins.png',
#  'RUV_1': 'Salad_planner_database_plots/RUV_1___Cherry_tomatoes.png',
#  'LFG_3': 'Salad_planner_database_plots/LFG_3___Cabbage.png',
#  'CRB_5': 'Salad_planner_database_plots/CRB_5___Butternut_squash_(air_fried-roasted).png',
#  'PRT_9': 'Salad_planner_database_plots/PRT_9___Gilled_salmon.png',
#  'FRT_8': 'Salad_planner_database_plots/FRT_8___Grapes.png',
#  'PRT_11': 'Salad_planner_database_plots/PRT_11___Grilled_shrimp.png',
#  'CRB_2': 'Salad_planner_database_plots/CRB_2___Pumpkin_(air_fried-roasted).png',
#  'HBF_1': 'Salad_planner_database_plots/HBF_1___Basil-Thai_basil.png',
#  'PRT_5': 'Salad_planner_database_plots/PRT_5___Pressed_tofu.png',
#  'CRB_3': 'Salad_planner_database_plots/CRB_3___Yam_(air_fried-roasted).png',
#  'LFG_8': 'Salad_planner_database_plots/LFG_8___Microgreens.png',
#  'FRT_9': 'Salad_planner_database_plots/FRT_9___Peaches.png',
#  'LFG_5': 'Salad_planner_database_plots/LFG_5___Spinach.png',
#  'PRT_14': 'Salad_planner_database_plots/PRT_14___Mixed_nuts.png',
#  'RUV_4': 'Salad_planner_database_plots/RUV_4___Green_peas.png',
#  'PRT_4': 'Salad_planner_database_plots/PRT_4___Hard_cheese_(1_oz_cube_or_shredded).png',
#  'RUV_7': 'Salad_planner_database_plots/RUV_7___Beets_(boiled).png',
#  'HBF_6': 'Salad_planner_database_plots/HBF_6___Sage.png',
#  'FRT_5': 'Salad_planner_database_plots/FRT_5___Figs.png',
#  'PRT_13': 'Salad_planner_database_plots/PRT_13___Ham.png',
#  'PRT_3': 'Salad_planner_database_plots/PRT_3___Low_fat_2%_cottage_cheese.png',
#  'FRT_7': 'Salad_planner_database_plots/FRT_7___Blackberries.png',
#  'CRB_9': 'Salad_planner_database_plots/CRB_9___Barley.png',
#  'PRT_7': 'Salad_planner_database_plots/PRT_7___Chick_peas.png',
#  'CRB_4': 'Salad_planner_database_plots/CRB_4___Parsnip_(air_fried-roasted).png',
#  'LFG_2': 'Salad_planner_database_plots/LFG_2___Lettuce.png',
#  'CRB_1': 'Salad_planner_database_plots/CRB_1___Sweet_potato_(air_fried-roasted).png',
#  'CRB_6': 'Salad_planner_database_plots/CRB_6___Potato_(air_fried-roasted).png',
#  'LDS_4': 'Salad_planner_database_plots/LDS_4___Balsamic_vinegar.png',
#  'CRB_16': 'Salad_planner_database_plots/CRB_16___Dried_plums.png',
#  'HBF_5': 'Salad_planner_database_plots/HBF_5___Thyme.png',
#  'RUV_2': 'Salad_planner_database_plots/RUV_2___Cucumbers.png',
#  'HBF_8': 'Salad_planner_database_plots/HBF_8___Jalapeno.png',
#  'CRB_12': 'Salad_planner_database_plots/CRB_12___Farro.png',
#  'HBF_10': 'Salad_planner_database_plots/HBF_10___Pickles.png',
#  'FRT_2': 'Salad_planner_database_plots/FRT_2___Dragon_fruit.png',
#  'PRT_2': 'Salad_planner_database_plots/PRT_2___Avocado.png',
#  'CRB_11': 'Salad_planner_database_plots/CRB_11___Brown_rice.png',
#  'SCV_2': 'Salad_planner_database_plots/SCV_2___Brussel_sprouts_(air_fried-roasted).png',
#  'RUV_6': 'Salad_planner_database_plots/RUV_6___Radishes.png',
#  'HBF_9': 'Salad_planner_database_plots/HBF_9___Olives_(black).png',
#  'HBF_4': 'Salad_planner_database_plots/HBF_4___Cilantro.png',
#  'LDS_2': 'Salad_planner_database_plots/LDS_2___Salt_&_Pepper.png',
#  'LFG_4': 'Salad_planner_database_plots/LFG_4___Kale.png',
#  'CRB_8': 'Salad_planner_database_plots/CRB_8___Quinoa.png',
#  'CRB_13': 'Salad_planner_database_plots/CRB_13___Dried_cranberries.png',
#  'PRT_6': 'Salad_planner_database_plots/PRT_6___Edamame.png',
#  'CRB_15': 'Salad_planner_database_plots/CRB_15___Dried_figs.png',
#  'RUV_5': 'Salad_planner_database_plots/RUV_5___Button_mushrooms.png',
#  'PRT_8': 'Salad_planner_database_plots/PRT_8___Roasted_chicken_breast.png',
#  'FRT_4': 'Salad_planner_database_plots/FRT_4___Pomegranate.png'}

# %%
text_link_to_main = "[Main Page](https://yolanda-ht.github.io/YoloCookBlob/)"
text_title = "# Salad Planner"
text_update_date = "> Updated: %s"%(datetime.today().strftime('%m/%d/%Y'))

with open(out_file, "w") as fout:
    wfout = csv.writer(fout, delimiter="\t")
    wfout.writerow([text_link_to_main])
    wfout.writerow([])
    wfout.writerow([text_title])
    wfout.writerow([text_update_date])
    wfout.writerow([])
    
    ###----- Write for each type
    # Order categories to use by calorie density
    type_list = list(db_df.groupby('Type').mean().sort_values('Calories per gram').index)
    for type_x in type_list:
        type_x_df = db_df[db_df['Type'] == type_x]
        type_x_name = " ".join(camel_case_split(type_x))

        type_x_header = "| %s |"%(" | ".join([type_emoji_dict[type_x] for x in range(col_n)]))
        type_x_sep = "| %s |"%(" | ".join([ "-" for x in range(col_n)]))

        wfout.writerow(["## %s"%type_x_name])
        wfout.writerow([type_x_header])
        wfout.writerow([type_x_sep ])

        # Write rows of table
        type_x_n = len(type_x_df)
        type_x_row = math.ceil(type_x_n / col_n)
        for row_i in range(type_x_row):
            row_i_range = [row_i*col_n, min((row_i+1)*col_n, len(type_x_df))]
            row_i_items = type_x_df.iloc[row_i_range[0]:row_i_range[1]]['ID'].tolist()
            row_i_list = ["![%s](%s)"%(row_i_item,plots_dict[row_i_item]) for row_i_item in row_i_items]
            row_i_list = row_i_list + [" " for fill_up_n in range(col_n - len(row_i_list))]
            row_i_content = "| %s |"%("|".join(row_i_list))
            wfout.writerow([row_i_content])
        wfout.writerow([])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [91], line 33
#      31 row_i_range = [row_i*col_n, min((row_i+1)*col_n, len(type_x_df))]
#      32 row_i_items = type_x_df.iloc[row_i_range[0]:row_i_range[1]]['ID'].tolist()
# ---> 33 row_i_list = ["![%s](%s)"%(row_i_item,plots_dict[row_i_item]) for row_i_item in row_i_items]
#      34 row_i_list = row_i_list + [" " for fill_up_n in range(col_n - len(row_i_list))]
#      35 row_i_content = "| %s |"%("|".join(row_i_list))
#
# Cell In [91], line 33, in <listcomp>(.0)
#      31 row_i_range = [row_i*col_n, min((row_i+1)*col_n, len(type_x_df))]
#      32 row_i_items = type_x_df.iloc[row_i_range[0]:row_i_range[1]]['ID'].tolist()
# ---> 33 row_i_list = ["![%s](%s)"%(row_i_item,plots_dict[row_i_item]) for row_i_item in row_i_items]
#      34 row_i_list = row_i_list + [" " for fill_up_n in range(col_n - len(row_i_list))]
#      35 row_i_content = "| %s |"%("|".join(row_i_list))
#
# KeyError: 'HDS_1'

# %%
plots_dict
# Out:
# {'RUV_3': 'Salad_planner_database_plots/RUV_3___Carrots.png',
#  'HBF_7': 'Salad_planner_database_plots/HBF_7___Roasted_garlic.png',
#  'FRT_3': 'Salad_planner_database_plots/FRT_3___Mango.png',
#  'LFG_6': 'Salad_planner_database_plots/LFG_6___Arugula.png',
#  'LFG_1': 'Salad_planner_database_plots/LFG_1___Mixed_Baby_Greens.png',
#  'FRT_10': 'Salad_planner_database_plots/FRT_10___Tangerines.png',
#  'CRB_10': 'Salad_planner_database_plots/CRB_10___Wild_rice.png',
#  'CRB_7': 'Salad_planner_database_plots/CRB_7___Corn.png',
#  'LDS_1': 'Salad_planner_database_plots/LDS_1___Sriracha.png',
#  'LFG_7': 'Salad_planner_database_plots/LFG_7___Endive.png',
#  'SCV_1': 'Salad_planner_database_plots/SCV_1___Broccoli-cauliflower_(air_fried-roasted).png',
#  'LDS_3': 'Salad_planner_database_plots/LDS_3___Lemon_juice.png',
#  'PRT_12': 'Salad_planner_database_plots/PRT_12___Bacon_crumbles.png',
#  'PRT_1': 'Salad_planner_database_plots/PRT_1___Hard_boiled_egg.png',
#  'FRT_1': 'Salad_planner_database_plots/FRT_1___Papaya.png',
#  'FRT_6': 'Salad_planner_database_plots/FRT_6___Strawberries.png',
#  'HBF_2': 'Salad_planner_database_plots/HBF_2___Mint-lemon_balm.png',
#  'HBF_3': 'Salad_planner_database_plots/HBF_3___Dill.png',
#  'PRT_10': 'Salad_planner_database_plots/PRT_10___Grilled_white_fish_(Tilapia).png',
#  'CRB_14': 'Salad_planner_database_plots/CRB_14___Raisins.png',
#  'RUV_1': 'Salad_planner_database_plots/RUV_1___Cherry_tomatoes.png',
#  'LFG_3': 'Salad_planner_database_plots/LFG_3___Cabbage.png',
#  'CRB_5': 'Salad_planner_database_plots/CRB_5___Butternut_squash_(air_fried-roasted).png',
#  'PRT_9': 'Salad_planner_database_plots/PRT_9___Gilled_salmon.png',
#  'FRT_8': 'Salad_planner_database_plots/FRT_8___Grapes.png',
#  'PRT_11': 'Salad_planner_database_plots/PRT_11___Grilled_shrimp.png',
#  'CRB_2': 'Salad_planner_database_plots/CRB_2___Pumpkin_(air_fried-roasted).png',
#  'HBF_1': 'Salad_planner_database_plots/HBF_1___Basil-Thai_basil.png',
#  'PRT_5': 'Salad_planner_database_plots/PRT_5___Pressed_tofu.png',
#  'CRB_3': 'Salad_planner_database_plots/CRB_3___Yam_(air_fried-roasted).png',
#  'LFG_8': 'Salad_planner_database_plots/LFG_8___Microgreens.png',
#  'FRT_9': 'Salad_planner_database_plots/FRT_9___Peaches.png',
#  'LFG_5': 'Salad_planner_database_plots/LFG_5___Spinach.png',
#  'PRT_14': 'Salad_planner_database_plots/PRT_14___Mixed_nuts.png',
#  'RUV_4': 'Salad_planner_database_plots/RUV_4___Green_peas.png',
#  'PRT_4': 'Salad_planner_database_plots/PRT_4___Hard_cheese_(1_oz_cube_or_shredded).png',
#  'RUV_7': 'Salad_planner_database_plots/RUV_7___Beets_(boiled).png',
#  'HBF_6': 'Salad_planner_database_plots/HBF_6___Sage.png',
#  'FRT_5': 'Salad_planner_database_plots/FRT_5___Figs.png',
#  'PRT_13': 'Salad_planner_database_plots/PRT_13___Ham.png',
#  'PRT_3': 'Salad_planner_database_plots/PRT_3___Low_fat_2%_cottage_cheese.png',
#  'FRT_7': 'Salad_planner_database_plots/FRT_7___Blackberries.png',
#  'CRB_9': 'Salad_planner_database_plots/CRB_9___Barley.png',
#  'PRT_7': 'Salad_planner_database_plots/PRT_7___Chick_peas.png',
#  'CRB_4': 'Salad_planner_database_plots/CRB_4___Parsnip_(air_fried-roasted).png',
#  'LFG_2': 'Salad_planner_database_plots/LFG_2___Lettuce.png',
#  'CRB_1': 'Salad_planner_database_plots/CRB_1___Sweet_potato_(air_fried-roasted).png',
#  'CRB_6': 'Salad_planner_database_plots/CRB_6___Potato_(air_fried-roasted).png',
#  'LDS_4': 'Salad_planner_database_plots/LDS_4___Balsamic_vinegar.png',
#  'CRB_16': 'Salad_planner_database_plots/CRB_16___Dried_plums.png',
#  'HBF_5': 'Salad_planner_database_plots/HBF_5___Thyme.png',
#  'RUV_2': 'Salad_planner_database_plots/RUV_2___Cucumbers.png',
#  'HBF_8': 'Salad_planner_database_plots/HBF_8___Jalapeno.png',
#  'CRB_12': 'Salad_planner_database_plots/CRB_12___Farro.png',
#  'HBF_10': 'Salad_planner_database_plots/HBF_10___Pickles.png',
#  'FRT_2': 'Salad_planner_database_plots/FRT_2___Dragon_fruit.png',
#  'PRT_2': 'Salad_planner_database_plots/PRT_2___Avocado.png',
#  'CRB_11': 'Salad_planner_database_plots/CRB_11___Brown_rice.png',
#  'SCV_2': 'Salad_planner_database_plots/SCV_2___Brussel_sprouts_(air_fried-roasted).png',
#  'RUV_6': 'Salad_planner_database_plots/RUV_6___Radishes.png',
#  'HBF_9': 'Salad_planner_database_plots/HBF_9___Olives_(black).png',
#  'HBF_4': 'Salad_planner_database_plots/HBF_4___Cilantro.png',
#  'LDS_2': 'Salad_planner_database_plots/LDS_2___Salt_&_Pepper.png',
#  'LFG_4': 'Salad_planner_database_plots/LFG_4___Kale.png',
#  'CRB_8': 'Salad_planner_database_plots/CRB_8___Quinoa.png',
#  'CRB_13': 'Salad_planner_database_plots/CRB_13___Dried_cranberries.png',
#  'PRT_6': 'Salad_planner_database_plots/PRT_6___Edamame.png',
#  'CRB_15': 'Salad_planner_database_plots/CRB_15___Dried_figs.png',
#  'RUV_5': 'Salad_planner_database_plots/RUV_5___Button_mushrooms.png',
#  'PRT_8': 'Salad_planner_database_plots/PRT_8___Roasted_chicken_breast.png',
#  'FRT_4': 'Salad_planner_database_plots/FRT_4___Pomegranate.png'}

# %%
row_i_content
# Out:
# '| ![LFG_6](Salad_planner_database_plots/LFG_6___Arugula.png)|![LFG_7](Salad_planner_database_plots/LFG_7___Endive.png)|![LFG_8](Salad_planner_database_plots/LFG_8___Microgreens.png)| |  |'

# %%
row_i_list
# Out:
# ['![LFG_6](Salad_planner_database_plots/LFG_6___Arugula.png)',
#  '![LFG_7](Salad_planner_database_plots/LFG_7___Endive.png)',
#  '![LFG_8](Salad_planner_database_plots/LFG_8___Microgreens.png)',
#  '',
#  '']

# %%
type_x_df.iloc[5:8]
# Out:
#           Type     ID         Name Category  Weight (g)  \
# 5  LeafyGreens  LFG_6      Arugula    Green        20.0
# 6  LeafyGreens  LFG_7       Endive    Green        37.5
# 7  LeafyGreens  LFG_8  Microgreens    Green        25.0
#
#    Calories per cup (240ml)  Fat (g)  Saturated fat (g)  Total Carb (g)  \
# 5                       4.0      0.1                0.0             0.7
# 6                       6.0      0.0                0.0             1.3
# 7                       5.0      0.0                0.0             1.0
#
#    Dietary fiber (g)  Sugar (g)  Protein (g)  Calories per each  \
# 5                0.4        0.4          0.5                NaN
# 6                1.2        0.1          0.5                NaN
# 7                1.0        1.0          1.0                NaN
#
#    Calories per tbsp (15ml)  Calories per gram
# 5                    0.2500               0.20
# 6                    0.3750               0.16
# 7                    0.3125               0.20

# %%
type_x_df
# Out:
#           Type     ID               Name Category  Weight (g)  \
# 0  LeafyGreens  LFG_1  Mixed Baby Greens    Green       227.0
# 1  LeafyGreens  LFG_2            Lettuce    Green        58.0
# 2  LeafyGreens  LFG_3            Cabbage    Green        89.0
# 3  LeafyGreens  LFG_4               Kale    Green       130.0
# 4  LeafyGreens  LFG_5            Spinach    Green       180.0
# 5  LeafyGreens  LFG_6            Arugula    Green        20.0
# 6  LeafyGreens  LFG_7             Endive    Green        37.5
# 7  LeafyGreens  LFG_8        Microgreens    Green        25.0
#
#    Calories per cup (240ml)  Fat (g)  Saturated fat (g)  Total Carb (g)  \
# 0                      68.0      0.0                0.0            13.6
# 1                       8.0      0.0                0.0             1.6
# 2                      22.0      0.0                0.0             5.0
# 3                      36.0      0.0                0.0             7.3
# 4                      41.0      0.5                0.1             6.8
# 5                       4.0      0.1                0.0             0.7
# 6                       6.0      0.0                0.0             1.3
# 7                       5.0      0.0                0.0             1.0
#
#    Dietary fiber (g)  Sugar (g)  Protein (g)  Calories per each  \
# 0                4.5        0.0          4.5                NaN
# 1                0.8        0.8          0.8                NaN
# 2                2.2        2.9          1.1                NaN
# 3                2.6        1.6          2.5                NaN
# 4                4.3        0.8          5.3                NaN
# 5                0.4        0.4          0.5                NaN
# 6                1.2        0.1          0.5                NaN
# 7                1.0        1.0          1.0                NaN
#
#    Calories per tbsp (15ml)  Calories per gram
# 0                    4.2500           0.299559
# 1                    0.5000           0.137931
# 2                    1.3750           0.247191
# 3                    2.2500           0.276923
# 4                    2.5625           0.227778
# 5                    0.2500           0.200000
# 6                    0.3750           0.160000
# 7                    0.3125           0.200000
